# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats

# %%
url = "https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv"
s_data = pd.read_csv(url)
print("Data imported successfully")
s_data.head(10)
# Out:
# Data imported successfully
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
# 5  2/22/2010               0.0           2098150.0             0.0
# 6  2/23/2010               0.0           2110700.0             0.0
# 7  2/24/2010               0.0           2120200.0             0.0
# 8  2/25/2010               0.0           2127600.0             0.0
# 9  2/26/2010               0.0           2136100.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# ...

# %%
s_data['btc_market_price'][1023]
# Out:
# 13.6888

# %%
sns.jointplot(x='btc_market_cap', y='btc_market_price', data=s_data)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
s_data.fillna("NULL")
# Out:
#       btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 0              0.00000           2043200.0    0.000000e+00      0.000000e+00
# 1              0.00000           2054650.0    0.000000e+00      0.000000e+00
# 2              0.00000           2063600.0    0.000000e+00      0.000000e+00
# 3              0.00000           2074700.0    0.000000e+00      0.000000e+00
# 4              0.00000           2085400.0    0.000000e+00      0.000000e+00
# ...                ...                 ...             ...               ...
# 2901       11524.77667          16830312.5    1.940000e+11      7.630946e+08
# 2902       11765.71000          16832287.5    1.980000e+11      7.381042e+08
# 2903       11212.65500          16834137.5    1.890000e+11      6.111197e+08
# 2904       10184.06167          16836225.0    1.710000e+11      1.266284e+09
# 2905       10125.01333          16837687.5    1.700000e+11      9.332398e+08
#
# ...

# %%
s_data.interpolate()
# Out:
#       btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 0              0.00000           2043200.0    0.000000e+00      0.000000e+00
# 1              0.00000           2054650.0    0.000000e+00      0.000000e+00
# 2              0.00000           2063600.0    0.000000e+00      0.000000e+00
# 3              0.00000           2074700.0    0.000000e+00      0.000000e+00
# 4              0.00000           2085400.0    0.000000e+00      0.000000e+00
# ...                ...                 ...             ...               ...
# 2901       11524.77667          16830312.5    1.940000e+11      7.630946e+08
# 2902       11765.71000          16832287.5    1.980000e+11      7.381042e+08
# 2903       11212.65500          16834137.5    1.890000e+11      6.111197e+08
# 2904       10184.06167          16836225.0    1.710000e+11      1.266284e+09
# 2905       10125.01333          16837687.5    1.700000e+11      9.332398e+08
#
# ...

# %%
s_data.fillna('NULL')
# Out:
#       btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 0              0.00000           2043200.0    0.000000e+00      0.000000e+00
# 1              0.00000           2054650.0    0.000000e+00      0.000000e+00
# 2              0.00000           2063600.0    0.000000e+00      0.000000e+00
# 3              0.00000           2074700.0    0.000000e+00      0.000000e+00
# 4              0.00000           2085400.0    0.000000e+00      0.000000e+00
# ...                ...                 ...             ...               ...
# 2901       11524.77667          16830312.5    1.940000e+11      7.630946e+08
# 2902       11765.71000          16832287.5    1.980000e+11      7.381042e+08
# 2903       11212.65500          16834137.5    1.890000e+11      6.111197e+08
# 2904       10184.06167          16836225.0    1.710000e+11      1.266284e+09
# 2905       10125.01333          16837687.5    1.700000e+11      9.332398e+08
#
# ...

# %%
input_col = ['btc_market_cap', 'btc_n_transactions', 'btc_miners_revenue' ,'btc_cost_per_transaction', 'btc_difficulty', 'btc_hash_rate', 'btc_cost_per_transaction_percent']
X=s_data[input_col]
Y=s_data['btc_market_price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)

# %%
linreg =LinearRegression()

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= linreg.predict(X_test)

# %%
from sklearn import metrics

# %%
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 432.8189944270004
