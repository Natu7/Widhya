# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv')

# %%
data.head()
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
data.tail()
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 265                         0      0       0
# 266                         0      0       0
# 267                         1      9       0
# 268                         0      0       0
# 269                         0      0       0

# %%
data.describe()
# Out:
#               Sno  ConfirmedIndianNational  ConfirmedForeignNational  \
# count  270.000000               270.000000                270.000000
# mean   135.500000                 5.551852                  1.329630
# std     78.086491                 8.339625                  3.587288
# min      1.000000                 0.000000                  0.000000
# 25%     68.250000                 1.000000                  0.000000
# 50%    135.500000                 3.000000                  0.000000
# 75%    202.750000                 6.000000                  0.000000
# max    270.000000                60.000000                 14.000000
#
#             Cured      Deaths
# count  270.000000  270.000000
# mean     0.603704    0.092593
# std      1.461522    0.290399
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.000000    0.000000
# max      9.000000    1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       270 non-null    int64
#  1   Date                      270 non-null    object
#  2   State/UnionTerritory      270 non-null    object
#  3   ConfirmedIndianNational   270 non-null    int64
#  4   ConfirmedForeignNational  270 non-null    int64
#  5   Cured                     270 non-null    int64
#  6   Deaths                    270 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 14.9+ KB

# %%
data.shape
# Out:
# (270, 7)

# %%
data['Total']=data['ConfirmedForeignNational']+data['ConfirmedIndianNational']+data['Cured']+data['Deaths']

# %%
df=data.groupby('Date',sort=False)[['ConfirmedForeignNational','ConfirmedIndianNational','Cured','Deaths','Total']].sum()

# %%
df.loc['04/03/20']
# Out:
# ConfirmedForeignNational    16
# ConfirmedIndianNational     12
# Cured                        3
# Deaths                       0
# Total                       31
# Name: 04/03/20, dtype: int64

# %%
df
# Out:
#           ConfirmedForeignNational  ConfirmedIndianNational  Cured  Deaths  \
# Date
# 30/01/20                         0                        1      0       0
# 31/01/20                         0                        1      0       0
# 01/02/20                         0                        2      0       0
# 02/02/20                         0                        3      0       0
# 03/02/20                         0                        3      0       0
# 04/02/20                         0                        3      0       0
# 05/02/20                         0                        3      0       0
# 06/02/20                         0                        3      0       0
# 07/02/20                         0                        3      0       0
# 08/02/20                         0                        3      0       0
# 09/02/20                         0                        3      0       0
# ...

# %%
plt.figure(figsize = (30,10))
plt.bar(data['Date'],data['Total'], color='yellow')
plt.xticks(rotation=45)
plt.show()

# %%
rates = []
for j in df['Total']:
    rates.append(((j+1)-(j))/j)

# %%
df['Spread_Rates']=rates
df
# Out:
#           ConfirmedForeignNational  ConfirmedIndianNational  Cured  Deaths  \
# Date
# 30/01/20                         0                        1      0       0
# 31/01/20                         0                        1      0       0
# 01/02/20                         0                        2      0       0
# 02/02/20                         0                        3      0       0
# 03/02/20                         0                        3      0       0
# 04/02/20                         0                        3      0       0
# 05/02/20                         0                        3      0       0
# 06/02/20                         0                        3      0       0
# 07/02/20                         0                        3      0       0
# 08/02/20                         0                        3      0       0
# 09/02/20                         0                        3      0       0
# ...

# %%
df1=df.loc['04/03/20':'21/03/20']

# %%
df1.mean()
# Out:
# ConfirmedForeignNational     19.888889
# ConfirmedIndianNational      77.666667
# Cured                         8.888889
# Deaths                        1.388889
# Total                       107.833333
# Spread_Rates                  0.015064
# dtype: float64

# %%
import math
r = 0.01506405
P_o = 31
t = 26
P_t = P_o*(math.exp(r*t))

# %%
print('forecast: ', P_t)
print('forecast: ', round(P_t, 0))
# Out:
# forecast:  45.862716233196544
# forecast:  46.0
